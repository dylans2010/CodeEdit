# %% [markdown]
# # {{PROJECT_NAME}}
#
# Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    'metric': ['A', 'B', 'C', 'D'],
    'value': [10, 25, 18, 32]
})
df.describe()
